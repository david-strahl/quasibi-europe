# %%
import networkx
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import importlib
import quasibi
import cartopy.crs as ccrs
importlib.reload(quasibi);

# %%
# load the correlation matrices
pearson = quasibi.load_symmat("../output/pearson_correlation_matrix.npy")
pearson = np.abs(pearson) >= np.quantile(np.abs(pearson), 0.995)

rmd     = quasibi.load_symmat("../output/rmd_correlation_matrix.npy")
rmd     = np.abs(rmd) >= np.quantile(np.abs(rmd), 0.995)

# %%
# load the distance matrix
D = quasibi.load_symmat("../output/distance.npy")

# load the latitude and longitude
LAT, LON = np.load("../output/latlon_nodes.npz").values()

# %%
S = 200
pearson_surrogates = quasibi.create_surrogate_adjacency_matrix(pearson, D, S)
rmd_surrogates     = quasibi.create_surrogate_adjacency_matrix(rmd, D, S)

# %% [markdown]
# ### Area Weighted Connectivity

# %%
# PV, PC, PB = quasibi.network_metric(pearson, quasibi.awc, pearson_surrogates, LAT=LAT)
# RV, RC, RB = quasibi.network_metric(rmd,     quasibi.awc, rmd_surrogates,     LAT=LAT)
# np.savez("../output/metrics/awc", PV, PC, PB, RV, RC, RB)
# Out:
# 100%|██████████| 200/200 [00:04<00:00, 41.89it/s]
# 100%|██████████| 200/200 [00:04<00:00, 42.29it/s]

# %% [markdown]
# ### Betweenness

# %%
# PV, PC, PB = quasibi.network_metric(pearson, quasibi.betweenness, pearson_surrogates)
# RV, RC, RB = quasibi.network_metric(rmd,     quasibi.betweenness, rmd_surrogates)
# np.savez("../output/metrics/betweenness", PV, PC, PB, RV, RC, RB)

# %% [markdown]
# ### Closeness

# %%
# PV, PC, PB = quasibi.network_metric(pearson, quasibi.closeness, pearson_surrogates)
# RV, RC, RB = quasibi.network_metric(rmd,     quasibi.closeness, rmd_surrogates)
# np.savez("../output/metrics/closeness", PV, PC, PB, RV, RC, RB)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 PV, PC, PB = quasibi.network_metric(pearson, quasibi.closeness, pearson_surrogates)
# ----> 2 RV, RC, RB = quasibi.network_metric(rmd,     quasibi.closeness, rmd_surrogates)
#       3 np.savez("../output/metrics/closeness", PV, PC, PB, RV, RC, RB)
#
# File ~/Documents/UP CLEWS/3 WS2023/NDA/Report/code/quasibi.py:318, in network_metric(A, func, surrogates, **kwargs)
#     315     return m
#     316 else:
#     317     M = np.mean(
# --> 318         [func(networkx.from_numpy_matrix(surrogate), **kwargs).reshape((25, 40)) for surrogate in surrogates],
#     319         axis=0)
#     320     return m, m - M, M
#
# File ~/Documents/UP CLEWS/3 WS2023/NDA/Report/code/quasibi.py:318, in <listcomp>(.0)
#     315     return m
#     316 else:
#     317     M = np.mean(
# --> 318         [func(networkx.from_numpy_matrix(surrogate), **kwargs).reshape((25, 40)) for surrogate in surrogates],
#     319         axis=0)
#     320     return m, m - M, M
#
# File ~/Documents/UP CLEWS/3 WS2023/NDA/Report/code/quasibi.py:303, in closeness(nx)
#     302 def closeness(nx):
# --> 303     return np.fromiter(networkx.closeness_centrality(nx).values(), dtype="float32")
#
# File /usr/local/Caskroom/miniconda/base/envs/NonLinearDA/lib/python3.10/site-packages/networkx/algorithms/centrality/closeness.py:120, in closeness_centrality(G, u, distance, wf_improved)
#     118 closeness_dict = {}
#     119 for n in nodes:
# --> 120     sp = path_length(G, n)
#     121     totsp = sum(sp.values())
#     122     len_G = len(G)
#
# File /usr/local/Caskroom/miniconda/base/envs/NonLinearDA/lib/python3.10/site-packages/networkx/algorithms/shortest_paths/unweighted.py:59, in single_source_shortest_path_length(G, source, cutoff)
#      57     cutoff = float("inf")
#      58 nextlevel = {source: 1}
# ---> 59 return dict(_single_shortest_path_length(G.adj, nextlevel, cutoff))
#
# File /usr/local/Caskroom/miniconda/base/envs/NonLinearDA/lib/python3.10/site-packages/networkx/algorithms/shortest_paths/unweighted.py:91, in _single_shortest_path_length(adj, firstlevel, cutoff)
#      89         return
#      90     for v in found:
# ---> 91         nextlevel.update(adj[v])
#      92     level += 1
#      93 del seen
#
# File /usr/local/Caskroom/miniconda/base/envs/NonLinearDA/lib/python3.10/site-packages/networkx/classes/coreviews.py:51, in AtlasView.__iter__(self)
#      50 def __iter__(self):
# ---> 51     return iter(self._atlas)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Clustering Coefficient

# %%
# PV, PC, PB = quasibi.network_metric(pearson, quasibi.clustering_coefficient, pearson_surrogates)
# RV, RC, RB = quasibi.network_metric(rmd,     quasibi.clustering_coefficient, rmd_surrogates)
# np.savez("../output/metrics/clustering_coefficient", PV, PC, PB, RV, RC, RB)
# Out:
# 100%|██████████| 200/200 [00:05<00:00, 37.08it/s]
# 100%|██████████| 200/200 [00:05<00:00, 37.89it/s]

# %% [markdown]
# # Plots

# %%
import matplotlib

def plot_metric(P, R, colorbar_title=""):

    # difference between pearson and rmd metric
    D  = (R - P)

    fig, axs = plt.subplots(3, 1, figsize=(6, 9), subplot_kw={"projection": ccrs.PlateCarree()})
    axs = axs.T.flatten()
    
    extent = [LON.min(), LON.max(), LAT.min(), LAT.max()]
    
    vmin=np.round(min(P.min(), R.min()), 3)
    vmax=np.round(max(P.max(), R.max()), 3)
    #norm = matplotlib.colors.TwoSlopeNorm(vmin=vmin, vcenter=0, vmax=vmax)
    
    # pearson uncorrected
    axs[0].set_title(r"$\bf{A}$ Pearson", loc="left")
    cmap = axs[0].imshow(P, cmap="Greens", extent=extent, vmin=vmin, vmax=vmax)
    cbar = plt.colorbar(cmap, ax=axs[0], label=colorbar_title)
    cbar.formatter.set_powerlimits([0, 0])
    
    # rmd uncorreded
    axs[1].set_title(r"$\bf{B}$ RMD", loc="left")
    cmap = axs[1].imshow(R, cmap="Greens", extent=extent, vmin=vmin, vmax=vmax)
    cbar = plt.colorbar(cmap, ax=axs[1], label=colorbar_title)
    cbar.formatter.set_powerlimits([0, 0])
    
    # difference
    axs[2].set_title(r"$\bf{C}$ RMD - Pearson", loc="left")
    cmap = axs[2].imshow(D, cmap="RdBu_r", vmin=-max(np.abs(D).max(), np.abs(D).max()), vmax=max(np.abs(D).max(), np.abs(D).max()), extent=extent)
    cbar = plt.colorbar(cmap, ax=axs[2], label=r"$\Delta\,$" + colorbar_title)
    cbar.formatter.set_powerlimits([0, 0])
    
    for ax in axs:
        ax.coastlines()

# %%
PV, PC, PB, RV, RC, RB = np.load("../output/metrics/awc.npz").values()
plot_metric(PC, RC, "AWC")
plt.savefig("../plots/awc.pdf", bbox_inches="tight")

# %%
PV, PC, PB, RV, RC, RB = np.load("../output/metrics/betweenness.npz").values()
plot_metric(PC, RC, "Betweenness")
plt.savefig("../plots/betweenness.pdf", bbox_inches="tight")

# %%
PV, PC, PB, RV, RC, RB = np.load("../output/metrics/closeness.npz").values()
plot_metric(PC, RC, "Closeness")
plt.savefig("../plots/closeness.pdf", bbox_inches="tight")

# %%
PV, PC, PB, RV, RC, RB = np.load("../output/metrics/clustering_coefficient.npz").values()
plot_metric(PC, RC, "CC")
plt.savefig("../plots/clustering_coefficient.pdf", bbox_inches="tight")

# %%
def closeness(nx, D):
    A = networkx.to_numpy_array(nx)
    D = np.nan_to_num(1/(D*A), posinf=0)
    return np.sum((A.shape[0]-1)*D, axis=0)

# %%
m = quasibi.network_metric(pearson, closeness, D=D)

plt.imshow(m, cmap="Greens")

# %%
net = networkx.from_numpy_matrix(pearson)

# %%
dist = {key: D[key[0], key[1]] for key in net.edges}
networkx.set_edge_attributes(net, dist, "dist")

# %%
# Out:
# {(0, 1): 60.82964984013286,
#  (1, 2): 60.82964984013268,
#  (2, 3): 60.82964984013286,
#  (3, 4): 60.82964984013276,
#  (4, 5): 60.82964984013276,
#  (5, 6): 60.82964984013276,
#  (7, 8): 60.82964984013276,
#  (8, 9): 60.82964984013286,
#  (11, 12): 60.82964984013276,
#  (12, 13): 60.82964984013276,
#  (13, 14): 60.82964984013278,
#  (14, 15): 60.82964984013276,
#  (15, 16): 60.82964984013278,
#  (16, 17): 60.82964984013278,
#  (17, 18): 60.82964984013278,
#  (17, 19): 121.64215600008255,
#  (18, 19): 60.82964984013278,
#  (18, 20): 121.64215600008257,
#  (19, 20): 60.82964984013278,
#  (20, 21): 60.82964984013276,
#  (21, 22): 60.82964984013276,
#  (21, 23): 121.64215600008257,
#  (22, 23): 60.829649840132824,
#  (22, 24): 121.64215600008257,
#  (23, 24): 60.82964984013276,
#  (23, 25): 121.64215600008257,
#  (24, 25): 60.829649840132824,
#  (24, 26): 121.64215600008257,
#  (25, 26): 60.82964984013276,
#  (25, 27): 121.64215600008252,
#  (26, 27): 60.82964984013276,
#  (26, 28): 121.64215600008252,
#  (27, 28): 60.82964984013276,
#  (27, 29): 121.64215600008252,
#  (28, 29): 60.82964984013276,
#  (28, 30): 121.64215600008252,
#  (29, 30): 60.82964984013276,
#  (29, 31): 121.64215600008252,
#  (30, 31): 60.82964984013276,
#  (30, 32): 121.64215600008252,
#  (31, 32): 60.82964984013276,
#  (31, 33): 121.64215600008261,
#  (32, 33): 60.82964984013286,
#  (32, 34): 121.64215600008252,
#  (33, 34): 60.82964984013268,
#  (33, 35): 121.64215600008252,
#  (34, 35): 60.82964984013286,
#  (34, 36): 121.64215600008252,
#  (35, 36): 60.82964984013268,
#  (35, 37): 121.64215600008252,
#  (36, 37): 60.82964984013286,
